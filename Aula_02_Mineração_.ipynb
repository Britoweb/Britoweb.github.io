# %% [markdown]
# <a href="https://colab.research.google.com/github/Britoweb/Britoweb.github.io/blob/master/Aula_02_Minera%C3%A7%C3%A3o_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando as bibliotecas
import pandas as pd
# %matplotlib inline
# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

dataset = pd.read_csv('sample_data/reclamacoes_consumidor.csv', sep=',',encoding='utf-8')

dataset.head(10)

#dataset.info()

#dataset.groupby('UF')['UF'].count()

#dataset['Grupo Problema'].value_counts()

#sns.set(style="darkgrid")
#sexo = dataset['Grupo Problema'].unique()
#cont = dataset["Grupo Problema"].value_counts()
#sns.barplot(x=sexo, y=cont)

#dataset[dataset['Grupo Problema'] == 'Cobrança / Contestação']['Problema']

dt2 = dataset[dataset['Grupo Problema'] == 'Cobrança / Contestação']
dt2['Problema'].value_counts().plot.barh()
# Out:
# Populating the interactive namespace from numpy and matplotlib
